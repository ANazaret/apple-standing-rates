# %%
from paper_analysis import analysis_table_control_group, analysis_to_latex_table, make_figure_5, make_figure_6
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 from paper_analysis import analysis_table_control_group, analysis_to_latex_table, make_figure_5, make_figure_6
#
# ImportError: cannot import name 'analysis_table_control_group' from 'paper_analysis' (/Users/achille/Documents/standing-causal/standing-rate-github/paper_analysis.py)

# %% [markdown]
# ## Generate tables

# %% [markdown]
# ### Linear regression tables

# %%
analysis_results = analysis_table_control_group(model="linear")

# %% [markdown]
# #### Relative effect (Table 1)

# %%
_ = analysis_to_latex_table(analysis_results, effect="relative", display_notebook=True)
# Out:
# time_of_day             $n$ users $m$ user-days  \
# variable       subgroup
# All            --         166,034    53,410,838
# age_group      18 -- 24    17,771     4,036,353
#                25 -- 34    41,307    11,974,775
#                35 -- 44    51,454    16,942,393
#                45 -- 54    27,443     9,760,343
#                55 -- 64    17,378     6,506,998
#                65 -- 74     7,851     3,048,398
#                75 -- 84     2,830     1,141,578
# biological_sex Female      57,731    16,480,598
#                Male       105,705    36,159,359
#                Other        2,598       770,881
# day_of_week    Weekday         --    38,666,387
#                Weekend         --    15,412,797
# energy_group   0 -- 49    119,202    36,413,085
#                50 -- 79    30,516    10,979,367
#                80 -- 99    13,251     5,264,921
#                100          2,583       727,971
# exercise_group 0 -- 49    119,202    36,413,085
# ...

# %% [markdown]
# #### Absolute effect (Table S1)

# %%
_ = analysis_to_latex_table(analysis_results, effect="absolute", display_notebook=True)
# Out:
# time_of_day             $n$ users $m$ user-days  \
# variable       subgroup
# All            --         166,034    53,410,838
# age_group      18 -- 24    17,771     4,036,353
#                25 -- 34    41,307    11,974,775
#                35 -- 44    51,454    16,942,393
#                45 -- 54    27,443     9,760,343
#                55 -- 64    17,378     6,506,998
#                65 -- 74     7,851     3,048,398
#                75 -- 84     2,830     1,141,578
# biological_sex Female      57,731    16,480,598
#                Male       105,705    36,159,359
#                Other        2,598       770,881
# day_of_week    Weekday         --    38,666,387
#                Weekend         --    15,412,797
# energy_group   0 -- 49    119,202    36,413,085
#                50 -- 79    30,516    10,979,367
#                80 -- 99    13,251     5,264,921
#                100          2,583       727,971
# exercise_group 0 -- 49    119,202    36,413,085
# ...

# %% [markdown]
# ### Logistic regression table (relative) (Table S2)

# %%
analysis_results = analysis_table_control_group(model="logistic")
_ = analysis_to_latex_table(analysis_results, effect="relative", display_notebook=True)
# Out:
# time_of_day             $n$ users $m$ user-days  \
# variable       subgroup
# All            --         166,034    53,410,838
# age_group      18 -- 24    17,771     4,036,353
#                25 -- 34    41,307    11,974,775
#                35 -- 44    51,454    16,942,393
#                45 -- 54    27,443     9,760,343
#                55 -- 64    17,378     6,506,998
#                65 -- 74     7,851     3,048,398
#                75 -- 84     2,830     1,141,578
# biological_sex Female      57,731    16,480,598
#                Male       105,705    36,159,359
#                Other        2,598       770,881
# day_of_week    Weekday         --    38,666,387
#                Weekend         --    15,412,797
# energy_group   0 -- 49    119,202    36,413,085
#                50 -- 79    30,516    10,979,367
#                80 -- 99    13,251     5,264,921
#                100          2,583       727,971
# exercise_group 0 -- 49    119,202    36,413,085
# ...

# %% [markdown]
# ## Generate figures

# %%
make_figure_5()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 make_figure_5()
#
# NameError: name 'make_figure_5' is not defined
